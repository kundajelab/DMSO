# %% [markdown]
# ## DESEQ2 analysis of 3 timepoints from GGR dataset
#
# 1 factor design
# * Day = 0,30,60
# * 225,996 naive overlap peaks
# * 2 biological replicates per Sample

# %%
rm(list=ls())
#load necessary libraries 
library(ggplot2)
library(DESeq2)
library("BiocParallel")
parallelFlag=TRUE
register(MulticoreParam(20))
library("IHW")
library("pheatmap")
# Out:
# Loading required package: S4Vectors
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colMeans,
#     colnames, colSums, dirname, do.call, duplicated, eval, evalq,
#     Filter, Find, get, grep, grepl, intersect, is.unsorted, lapply,
#     lengths, Map, mapply, match, mget, order, paste, pmax, pmax.int,
#     pmin, pmin.int, Position, rank, rbind, Reduce, rowMeans, rownames,
#     rowSums, sapply, setdiff, sort, table, tapply, union, unique,
#     unsplit, which, which.max, which.min
#
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
# Loading required package: IRanges
# Loading required package: GenomicRanges
# Loading required package: GenomeInfoDb
# Loading required package: SummarizedExperiment
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
# Loading required package: DelayedArray
# Loading required package: matrixStats
#
# Attaching package: ‘matrixStats’
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
# Loading required package: BiocParallel
#
# Attaching package: ‘DelayedArray’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colMaxs, colMins, colRanges, rowMaxs, rowMins, rowRanges
#
# The following objects are masked from ‘package:base’:
#
#     aperm, apply
#
#
# Attaching package: ‘IHW’
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha

# %% [markdown]
# ## Load data and design

# %%
#load ATAC-seq raw read counts
data=read.table('subset.counts.txt',header=TRUE,sep='\t')
#concatenate chrom/start/end columns values to server as rownames for the dataframe of the form chrom_start_end 
rownames(data)=paste(data$Chrom,data$Start,data$End,sep="_")
data$Chrom=NULL
data$Start=NULL
data$End=NULL

# %%
head(data)
# Out:
#                    d00_b1 d00_b2 d30_b1 d30_b2 d60_b1 d60_b2
# chr1_10044_10643    71     120   108     103    52     50
# chr1_127686_127881  12      28    20      29     4     28
# chr1_237637_237882  91      50    73      41    38     26
# chr1_521454_521687  40     140    39      92    12     68
# chr1_713676_714708 861    1231   764    1336   192    453
# chr1_755160_755774  39      56    62      75    41     95

# %%
#load the metadata
batches=read.table("batches.txt",header=TRUE,sep='\t',row.names=1)
batches$Day=factor(batches$Day)

# %%
head(batches)
# Out:
#        Day
# d00_b1 d0
# d00_b2 d0
# d30_b1 d30
# d30_b2 d30
# d60_b1 d60
# d60_b2 d60

# %%
#Create DESeq object
dds <- DESeqDataSetFromMatrix(countData = data,
                              colData = batches,
                              design = ~Day)

# %% [markdown]
# ## Visualizations

# %%
#PCA on vst-transformed data
vst_data=vst(dds)
source('plotPCA_custom.R')
plotPCA_custom(vst_data,intgroup=c("Day"),ntop=nrow(data),returnData=FALSE,pcx=1,pcy=2)
plotPCA_custom(vst_data,intgroup=c("Day"),ntop=nrow(data),returnData=FALSE,pcx=2,pcy=3)
# Out:
# plot without title
# plot without title

# %%
#perform size factor estimation for for housekeeping (HK) promoters
hk_promoters=read.table("HK.promoters.txt",header=TRUE,sep='\t')
hk_promoters=paste(hk_promoters$Chrom,hk_promoters$Start,hk_promoters$End,sep="_")
hk_promoter_indices=na.omit(match(hk_promoters,rownames(data)))

# %%
dds <- estimateSizeFactors(dds, controlGenes=hk_promoter_indices)

# %%
#PCA on vst-transformed data w/ custom sizeFactors
# shifted log of normalized counts
se <- SummarizedExperiment(log2(counts(dds, normalized=TRUE) + 1),
                           colData=colData(dds))
# the call to DESeqTransform() is needed to
# trigger our plotPCA method.
plotPCA_custom( DESeqTransform( se ),intgroup=c("Day"),pcx=1,pcy=2)
plotPCA_custom( DESeqTransform( se ),intgroup=c("Day"),pcx=2,pcy=3)
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## Differential Accessibility Operation

# %%
#Run the differential analysis
dds <- DESeq(dds,parallel = FALSE)
# Out:
# using pre-existing size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing

# %%
plotDispEsts(dds)
# Out:
# plot without title

# %%
plotMA(dds)
# Out:
# Plot with title “”

# %% [markdown]
# ## Standard BH Correction (no optimal thresholding)

# %%
resultsNames(dds)
# Out:
# [1] "Intercept"     "Day_d30_vs_d0" "Day_d60_vs_d0"

# %%
res=results(dds)
summary(res)
# Out:
# out of 225996 with nonzero total read count
# adjusted p-value < 0.1
# LFC > 0 (up)       : 76442, 34%
# LFC < 0 (down)     : 21107, 9.3%
# outliers [1]       : 0, 0%
# low counts [2]     : 0, 0%
# (mean count < 6)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results

# %%
namesToOutput=c("Day_d30_vs_d0",
"Day_d60_vs_d0")
numcomparisons=length(namesToOutput)

# %%
for(i in seq(1,numcomparisons))
{
 res=results(dds,name=namesToOutput[i],parallel=TRUE)
 res$logPadj=-10*log10(res$padj)
 res=as.data.frame(res)
 res=na.omit(res)
 numsig=sum(res$padj <= 0.05)
 sigsubset=res[res$padj<=0.05,]

 #output differential analysis results for the contrast
 #outtable=paste(namesToOutput[i],"tsv",sep='.')
 #write.table(sigsubset,file=outtable,quote=FALSE,sep='\t',row.names=TRUE,col.names=TRUE)
 #print(paste(namesToOutput[i],numsig))

 #generate a volcano plot of the differential analysis for the contrast
 #outpng=paste("volcano",namesToOutput[i],"png",sep='.')
 outlabel=paste(namesToOutput[i],"Diff. peaks:",numsig)
 res$color=res$padj<=0.05

 #png(outpng)#,width=5,height=5,pointsize=12)
 print(ggplot(data=res,
        aes(x=res$log2FoldChange,
            y=res$logPadj,
            color=res$color))+
        geom_point()+
        xlab("Log2(FC)")+
        ylab("-10*log10(P-adj)")+
        ggtitle(outlabel)+
        scale_color_manual(values=c("#000000","#ff0000"),name="P.adj<0.05"))
 #dev.off()
}

 res=results(dds,contrast=list("Day_d60_vs_d0","Day_d30_vs_d0"),parallel=TRUE)
 res$logPadj=-10*log10(res$padj)
 res=as.data.frame(res)
 res=na.omit(res)
 numsig=sum(res$padj <= 0.05)
 sigsubset=res[res$padj<=0.05,]

 #output differential analysis results for the contrast
 #outtable=paste(namesToOutput[i],"tsv",sep='.')
 #write.table(sigsubset,file=outtable,quote=FALSE,sep='\t',row.names=TRUE,col.names=TRUE)
 #print(paste(namesToOutput[i],numsig))

 #generate a volcano plot of the differential analysis for the contrast
 #outpng=paste("volcano",namesToOutput[i],"png",sep='.')
 outlabel=paste("Day_d60_v_d30","Diff. peaks:",numsig)
 res$color=res$padj<=0.05

 #png(outpng)#,width=5,height=5,pointsize=12)
 print(ggplot(data=res,
        aes(x=res$log2FoldChange,
            y=res$logPadj,
            color=res$color))+
        geom_point()+
        xlab("Log2(FC)")+
        ylab("-10*log10(P-adj)")+
        ggtitle(outlabel)+
        scale_color_manual(values=c("#000000","#ff0000"),name="P.adj<0.05"))
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Find an Optimal Filtering Threshold with -log10Pval v baseMean

# %%
res=results(dds)
res$filtRatio=-log10(res$pvalue)/res$baseMean
res_df=as.data.frame(res[order(-res$filtRatio),])

# %%
ggplot(data=res_df,
       aes(x=log10(res_df$baseMean),
           y=-log10(res_df$pvalue)))+
       geom_point(alpha=0.1)+
       xlab("log10(baseMean)")+
       ylab("-log10(pvalue)")+
       theme_bw(20)
# Out:
# plot without title

# %% [markdown]
# ## Find an optimal filtering threshold with IHW

# %%
library("IHW")
resIHW=results(dds,filterFun=ihw)
summary(resIHW)
# Out:
# out of 225996 with nonzero total read count
# adjusted p-value < 0.1
# LFC > 0 (up)       : 76520, 34%
# LFC < 0 (down)     : 21014, 9.3%
# outliers [1]       : 0, 0%
# [1] see 'cooksCutoff' argument of ?results
# see metadata(res)$ihwResult on hypothesis weighting

# %%
sum(resIHW$padj < 0.1, na.rm=TRUE)
# Out:
# [1] 97534

# %%
plot(metadata(resIHW)$ihwResult)
# Out:
# plot without title

# %% [markdown]
# ## Independent Filtering

# %%
metadata(res)$alpha
# Out:
# [1] 0.1

# %%
metadata(res)$filterThreshold
# Out:
#       0%
# 6.367802

# %%
plot(metadata(res)$filterNumRej, 
     type="b", ylab="number of rejections",
     xlab="quantiles of filter")
lines(metadata(res)$lo.fit, col="red")
abline(v=metadata(res)$filterTheta)
# Out:
# plot without title

# %%
resNoFilt <- results(dds, independentFiltering=FALSE)
addmargins(table(filtering=(res$padj < .1),
                 noFiltering=(resNoFilt$padj < .1)))
# Out:
#          noFiltering
# filtering FALSE  TRUE  Sum
#     FALSE 128447     0 128447
#     TRUE       0 97549  97549
#     Sum   128447 97549 225996

# %%
summary(resNoFilt)
# Out:
# out of 225996 with nonzero total read count
# adjusted p-value < 0.1
# LFC > 0 (up)       : 76442, 34%
# LFC < 0 (down)     : 21107, 9.3%
# outliers [1]       : 0, 0%
# low counts [2]     : 0, 0%
# (mean count < 0)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
